# %%
import math
from math import sqrt
negativo = "La ecuación de segundo grado no tiene solución en el conjunto de los números reales."
a = float(input("Ingrese valor de a: "))
b = float(input("Ingrese valor de b: "))
c = float(input("Ingrese valor de c: "))
if b ** 2 - 4 * a * c >= 0:
    x1 = (-b - sqrt(b ** 2 - 4 * a * c)) /( 2 * a)
    x2 = (-b + sqrt(b ** 2 - 4 * a * c)) / (2 * a)
    print("x1: ",x1)
    print("x2: ",x2)
else:
    print(negativo)
# Out:
# Ingrese valor de a: -7.5
# Ingrese valor de b: 17.9
# Ingrese valor de c: 21.3
# x1:  3.258289614818354
# x2:  -0.8716229481516876
